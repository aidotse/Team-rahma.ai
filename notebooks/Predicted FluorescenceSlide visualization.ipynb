# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os

# %%
pred_fns = [
    '../tmp/test_slides/predicted_60_256/AssayPlate_Greiner_#655090_B03_T0001F004L01A01Z01C01.tif',
    '../tmp/test_slides/predicted_60_256/AssayPlate_Greiner_#655090_B03_T0001F004L01A02Z01C02.tif',
    '../tmp/test_slides/predicted_60_256/AssayPlate_Greiner_#655090_B03_T0001F004L01A03Z01C03.tif'
]

gt_fns = [
    '../tmp/test_slides/target_60_256/AssayPlate_Greiner_#655090_B03_T0001F004L01A01Z01C01.tif',
    '../tmp/test_slides/target_60_256/AssayPlate_Greiner_#655090_B03_T0001F004L01A02Z01C02.tif',
    '../tmp/test_slides/target_60_256/AssayPlate_Greiner_#655090_B03_T0001F004L01A03Z01C03.tif'
]

preds = [cv2.imread(fn,-1) for fn in pred_fns]
pred = np.stack(preds, axis=2) / (256.*256.)

gts = [cv2.imread(fn,-1) for fn in gt_fns]
gt = np.stack(gts, axis=2) / (256.*256.)

pred.shape
# Out:
# (2156, 2556, 3)

# %%
plt.imshow(np.clip(pred*30, 0,1.))

# %%
plt.imshow(np.clip(gt*30, 0,1.))
